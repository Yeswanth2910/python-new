# %% [markdown]
# <a href="https://colab.research.google.com/github/Yeswanth2910/python-new/blob/module-4/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xcoordinates = np.array([1, 9])
ycoordinates= np.array([3, 10])

plt.plot(xcoordinates, ycoordinates)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xcoordinates = np.array([2, 8])
ycoordinates= np.array([4, 9])

plt.plot(xcoordinates, ycoordinates, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xcoordinates = np.array([2, 4, 6, 8])
ycoordinates= np.array([1, 3, 5, 7])

plt.plot(xcoordinates, ycoordinates)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ycoordinates = np.array([1, 3, 5, 1, 5, 7])

plt.plot(ycoordinates)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ycoordinates = np.array([5, 6, 8, 10])

plt.plot(ycoordinates, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ycoordinates = np.array([1, 4, 1, 10])

plt.plot(ycoordinates, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ycoordinates = np.array([1, 4, 8, 10])

plt.plot(ycoordinates, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ycoordinates = np.array([1, 5, 2, 8])
plt.plot(ycoordinates, linewidth = '20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([1, 3, 9, 4])
x2 = np.array([4, 2, 11, 4])

plt.plot(x1)
plt.plot(x2)

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([5, 4, 3, 2])
x1 = np.array([7, 4, 4, 10])
y2 = np.array([4, 7, 2, 3])
x2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
#matplotlib lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array([40, 59, 70, 85, 90, 105, 110, 115, 120, 125])
y = np.array([240, 270, 290, 290, 280, 310, 300, 310, 330, 340])

plt.plot(x, y)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 110, 115, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70,79, 60, 80,105, 120, 115, 120, 135])
y = np.array([245, 230, 240, 275, 210, 250, 300, 310, 330])

plt.plot(x, y)
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt

x = np.array([50, 75, 40, 85, 95, 75, 110, 115, 150, 125])
y = np.array([200, 150, 260, 170, 280, 390, 300, 410, 320, 330])

plt.plot(x, y)

plt.grid()

plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x, y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x, y, color = "red")
plt.show()
